# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("data jumlah KK tahun 2020.csv")

# %%
df
# Out:
#       tahun nama_provinsi    nama_kabupaten/kota          nama_kecamatan  \
# 0      2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 1      2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 2      2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 3      2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 4      2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# ...     ...           ...                    ...                     ...
# 1221   2020   DKI JAKARTA          JAKARTA TIMUR                CIPAYUNG
# 1222   2020   DKI JAKARTA          JAKARTA TIMUR                CIPAYUNG
# 1223   2020   DKI JAKARTA          JAKARTA TIMUR                CIPAYUNG
# 1224   2020   DKI JAKARTA          JAKARTA TIMUR                CIPAYUNG
# 1225   2020   DKI JAKARTA          JAKARTA TIMUR                CIPAYUNG
#
#      jenis_kelamin   usia  jumlah
# 0        LAKI-LAKI    <15       1
# ...

# %%
df.head(5)
# Out:
#    tahun nama_provinsi    nama_kabupaten/kota          nama_kecamatan  \
# 0   2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 1   2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 2   2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 3   2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
# 4   2020   DKI JAKARTA  ADM. KEPULAUAN SERIBU  KEPULAUAN SERIBU UTARA
#
#   jenis_kelamin   usia  jumlah
# 0     LAKI-LAKI    <15       1
# 1     LAKI-LAKI  15-19       4
# 2     LAKI-LAKI  20-24      98
# 3     LAKI-LAKI  25-29     415
# 4     LAKI-LAKI  30-34     552

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tahun                1226 non-null   int64
#  1   nama_provinsi        1226 non-null   object
#  2   nama_kabupaten/kota  1226 non-null   object
#  3   nama_kecamatan       1226 non-null   object
#  4   jenis_kelamin        1226 non-null   object
#  5   usia                 1226 non-null   object
#  6   jumlah               1226 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 67.2+ KB

# %%
df.isnull().sum()
# Out:
# tahun                  0
# nama_provinsi          0
# nama_kabupaten/kota    0
# nama_kecamatan         0
# jenis_kelamin          0
# usia                   0
# jumlah                 0
# dtype: int64

# %%
df['nama_kecamatan'].value_counts()
# Out:
# KEPULAUAN SERIBU UTARA      28
# KALI DERES                  28
# MAMPANG PRAPATAN            28
# PASAR MINGGU                28
# KEBAYORAN LAMA              28
# CILANDAK                    28
# KEBAYORAN BARU              28
# PANCORAN                    28
# JAGAKARSA                   28
# PESANGGRAHAN                28
# MATRAMAN                    28
# PULO GADUNG                 28
# JATINEGARA                  28
# KRAMATJATI                  28
# PASAR REBO                  28
# CAKUNG                      28
# DUREN SAWIT                 28
# MAKASAR                     28
# CIRACAS                     28
# KEMBANGAN                   28
# PAL MERAH                   28
# KEBON JERUK                 28
# TANJUNG PRIOK               28
# GAMBIR                      28
# SAWAH BESAR                 28
# KEMAYORAN                   28
# S E N E N                   28
# CEMPAKA PUTIH               28
# MENTENG                     28
# TANAH ABANG                 28
# ...

# %%
df['usia'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         <15
# 1       15-19
# 2       20-24
# 3       25-29
# 4       30-34
#         ...
# 1221    55-59
# 1222    60-64
# 1223    65-69
# 1224    70-75
# 1225      >75
# Name: usia, Length: 1226, dtype: object>

# %%
na = df.groupby(['nama_kecamatan', 'jenis_kelamin', 'usia'])

# %%
na.first()
# Out:
#                                     tahun nama_provinsi nama_kabupaten/kota  \
# nama_kecamatan jenis_kelamin usia
# CAKUNG         LAKI-LAKI     15-19   2020   DKI JAKARTA       JAKARTA TIMUR
#                              20-24   2020   DKI JAKARTA       JAKARTA TIMUR
#                              25-29   2020   DKI JAKARTA       JAKARTA TIMUR
#                              30-34   2020   DKI JAKARTA       JAKARTA TIMUR
#                              35-39   2020   DKI JAKARTA       JAKARTA TIMUR
# ...                                   ...           ...                 ...
# TEBET          PEREMPUAN     55-59   2020   DKI JAKARTA     JAKARTA SELATAN
#                              60-64   2020   DKI JAKARTA     JAKARTA SELATAN
#                              65-69   2020   DKI JAKARTA     JAKARTA SELATAN
#                              70-75   2020   DKI JAKARTA     JAKARTA SELATAN
#                              >75     2020   DKI JAKARTA     JAKARTA SELATAN
#
# ...

# %%
df['usia'].value_counts()
# Out:
# 15-19    88
# 20-24    88
# 25-29    88
# 30-34    88
# 35-39    88
# 40-44    88
# 45-49    88
# 50-54    88
# 55-59    88
# 60-64    88
# 65-69    88
# 70-75    88
# >75      88
# <15      82
# Name: usia, dtype: int64

# %%
total = df['jumlah'].sum()

# %%
total
# Out:
# 3614985

# %%
df['nama_kabupaten/kota'].sum()
# Out:
# 'ADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUADM. KEPULAUAN SERIBUJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJAKARTA PUSATJ
# ...

# %%
sns.boxplot(x="nama_kabupaten/kota",y="jumlah",data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tahun                1226 non-null   int64
#  1   nama_provinsi        1226 non-null   object
#  2   nama_kabupaten/kota  1226 non-null   object
#  3   nama_kecamatan       1226 non-null   object
#  4   jenis_kelamin        1226 non-null   object
#  5   usia                 1226 non-null   object
#  6   jumlah               1226 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 67.2+ KB

# %%
df.plot(kind="scatter", x="usia", y="jumlah")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='usia', ylabel='jumlah'>

# %%
sns.FacetGrid(df, hue="nama_kabupaten/kota", height=5) \
   .map(plt.scatter, "usia", "jumlah") \
   .add_legend()
plt.show()

# %%
g = df.groupby(['nama_kabupaten/kota', 'jumlah', 'usia'])
g.first()
# Out:
#                                     tahun nama_provinsi  \
# nama_kabupaten/kota   jumlah usia
# ADM. KEPULAUAN SERIBU 0      <15     2020   DKI JAKARTA
#                       1      15-19   2020   DKI JAKARTA
#                              <15     2020   DKI JAKARTA
#                       4      15-19   2020   DKI JAKARTA
#                       11     20-24   2020   DKI JAKARTA
# ...                                   ...           ...
# JAKARTA UTARA         15036  45-49   2020   DKI JAKARTA
#                       16788  35-39   2020   DKI JAKARTA
#                       17044  40-44   2020   DKI JAKARTA
#                       18176  40-44   2020   DKI JAKARTA
#                       18731  35-39   2020   DKI JAKARTA
#
#                                               nama_kecamatan jenis_kelamin
# nama_kabupaten/kota   jumlah usia
# ADM. KEPULAUAN SERIBU 0      <15      KEPULAUAN SERIBU UTARA     PEREMPUAN
# ...
